# %%
import pandas as pd
import torch
import numpy as np
import os

# %%
i = 0
meta = pd.read_csv('TCGA-Normal//MANIFEST.txt',sep='\t')

# %%
meta
# Out:
#                                        id  \
# 0    00252d7f-e222-462f-badc-b97e8dce2021
# 1    007f9390-1d58-4665-b3be-46b3e7219194
# 2    0149679a-8220-47ba-9060-eda9329bee70
# 3    01851b83-f8c4-4108-99c9-248fe29e39e9
# 4    01aeccaf-0178-43d7-8273-b0bf9eeacddb
# ..                                    ...
# 792                                    \N
# 793                                    \N
# 794                                    \N
# 795                                    \N
# 796                                    \N
#
#                                               filename  \
# 0    00252d7f-e222-462f-badc-b97e8dce2021/5abd235a-...
# 1    007f9390-1d58-4665-b3be-46b3e7219194/9a856422-...
# 2    0149679a-8220-47ba-9060-eda9329bee70/2e7d0821-...
# 3    01851b83-f8c4-4108-99c9-248fe29e39e9/6dd12311-...
# 4    01aeccaf-0178-43d7-8273-b0bf9eeacddb/0fd97692-...
# ..                                                 ...
# 792  efb3bf8d-7d14-42d6-8845-e81af909d47f/annotatio...
# ...

# %%
cases = []
i = 0
for root, subdirs, f in os.walk('TCGA-Normal'):
    if f[0][-3:] == 'tsv':
        file_path = os.path.join(root, f[0])
        df = pd.read_csv(file_path,sep='\t',header=1)
        print(df.columns)
        # df = df[['gene_name','tpm_unstranded']]
        # df = df.iloc[4:,]
        # df = df.set_index(df.columns[0])
        # df = df.T
        # if i ==0:
        #     data = df
        # else:
        #     data = pd.concat([data, df])
        #     print(data.shape)
        # i +=1
# Out:
# Index(['gene_id', 'gene_name', 'gene_type', 'unstranded', 'stranded_first',
#        'stranded_second', 'tpm_unstranded', 'fpkm_unstranded',
#        'fpkm_uq_unstranded'],
#       dtype='object')
# Index(['gene_id', 'gene_name', 'gene_type', 'unstranded', 'stranded_first',
#        'stranded_second', 'tpm_unstranded', 'fpkm_unstranded',
#        'fpkm_uq_unstranded'],
#       dtype='object')
# Index(['gene_id', 'gene_name', 'gene_type', 'unstranded', 'stranded_first',
#        'stranded_second', 'tpm_unstranded', 'fpkm_unstranded',
#        'fpkm_uq_unstranded'],
#       dtype='object')
# Index(['gene_id', 'gene_name', 'gene_type', 'unstranded', 'stranded_first',
#        'stranded_second', 'tpm_unstranded', 'fpkm_unstranded',
#        'fpkm_uq_unstranded'],
#       dtype='object')
# Index(['gene_id', 'gene_name', 'gene_type', 'unstranded', 'stranded_first',
#        'stranded_second', 'tpm_unstranded', 'fpkm_unstranded',
#        'fpkm_uq_unstranded'],
#       dtype='object')
# ...

# %%
data
# Out:
# gene_name        TSPAN6    TNMD     DPM1    SCYL3  C1orf112       FGR  \
# tpm_unstranded  24.1580  5.9454  91.6577   4.6748    1.3317   16.0564
# tpm_unstranded  43.8078  0.8866  98.4375  10.5073    2.1921   18.5738
# tpm_unstranded  35.3706  0.0834  80.6319   6.7033    1.1747   67.0122
# tpm_unstranded  65.8275  5.9684  66.4174   6.7834    1.5921   10.1450
# tpm_unstranded  40.1384  2.3845  85.7395  12.4982    4.3988   32.7809
# ...                 ...     ...      ...      ...       ...       ...
# tpm_unstranded  16.1285  0.0354  71.4435   4.8700    1.2438   59.7775
# tpm_unstranded  43.1156  0.0332  34.0884   2.5863    0.4189    2.7986
# tpm_unstranded   5.4947  0.0646  55.8640   4.8543    1.0544    5.2170
# tpm_unstranded  14.0749  0.0000  61.7870   4.1584    1.4649  124.1492
# tpm_unstranded  77.1195  0.0000  78.4028   7.1245    1.8281    3.8150
#
# gene_name            CFH    FUCA2     GCLC     NFYA  ...  AL451106.1  \
# ...

# %%
X= torch.load('preprocessed/X.pt')

# %%
data2 = data[X.columns]
data2
# Out:
# gene_name       LINC00115   SAMD11    NOC2L  KLHL17  PLEKHN1     HES4  \
# tpm_unstranded     1.0821  13.4443  35.9450  4.1228   0.2608  17.1744
# tpm_unstranded     0.8368  14.1783  49.5696  4.1100   2.7942  26.5530
# tpm_unstranded     0.3737   1.6806  33.6688  3.2911   0.6774  21.3500
# tpm_unstranded     1.0562  11.6552  35.1172  5.6969   0.6180  12.7733
# tpm_unstranded     2.0043   1.6868  40.3533  6.1277   4.2167  11.8657
# ...                   ...      ...      ...     ...      ...      ...
# tpm_unstranded     0.5559   1.5414  31.4612  2.9359   0.7425  10.7581
# tpm_unstranded     0.3724   1.3867  11.9679  1.0811   0.1279   2.3248
# tpm_unstranded     2.2208   2.3845  12.5498  2.5511   0.1105  36.4824
# tpm_unstranded     0.7244   1.3337  32.6205  4.8844   0.8755   6.9692
# tpm_unstranded     2.3939  15.3429  50.0191  3.3933   8.1801  18.6122
#
# gene_name          ISG15      AGRN  TTLL10  TNFRSF18  ...      ZFY  PCDH11Y  \
# ...

# %%
X
# Out:
#        LINC00115    SAMD11       NOC2L     KLHL17    PLEKHN1       HES4  \
# Pat02   6.610000  4.240000   53.690000  16.920000   1.710000  12.030000
# Pat03   3.770000  0.610000   65.960000   9.130000  19.900000   7.560000
# Pat04   2.470000  0.570000   74.390000  17.760000   0.430000   2.110000
# Pat06   8.790000  1.310000   51.070000   9.700000   1.670000   4.250000
# Pat08   4.220000  0.630000   80.800000   6.470000   0.410000   1.440000
# ...          ...       ...         ...        ...        ...        ...
# Pt35   24.696013  0.092566  173.951860  23.641068   1.222484  51.348978
# Pt37   14.947634  0.579756   92.229980  18.987374   2.734513  76.337669
# Pt38    9.856867  1.749638   56.245350  15.517608   0.296242  46.710147
# Pt28    3.767220  0.053343   54.905231  14.052876  19.314726  11.836474
# Pt29   23.815700  1.180298   49.404329  30.569655  35.143880  73.942557
#
#             ISG15        AGRN    TTLL10   TNFRSF18  ...        ZFY   PCDH11Y  \
# ...

# %%
torch.save(data2,'tcga_normal.pt')

# %%
data2
# Out:
# gene_name       LINC00115   SAMD11    NOC2L  KLHL17  PLEKHN1     HES4  \
# tpm_unstranded     1.0821  13.4443  35.9450  4.1228   0.2608  17.1744
# tpm_unstranded     0.8368  14.1783  49.5696  4.1100   2.7942  26.5530
# tpm_unstranded     0.3737   1.6806  33.6688  3.2911   0.6774  21.3500
# tpm_unstranded     1.0562  11.6552  35.1172  5.6969   0.6180  12.7733
# tpm_unstranded     2.0043   1.6868  40.3533  6.1277   4.2167  11.8657
# ...                   ...      ...      ...     ...      ...      ...
# tpm_unstranded     0.5559   1.5414  31.4612  2.9359   0.7425  10.7581
# tpm_unstranded     0.3724   1.3867  11.9679  1.0811   0.1279   2.3248
# tpm_unstranded     2.2208   2.3845  12.5498  2.5511   0.1105  36.4824
# tpm_unstranded     0.7244   1.3337  32.6205  4.8844   0.8755   6.9692
# tpm_unstranded     2.3939  15.3429  50.0191  3.3933   8.1801  18.6122
#
# gene_name          ISG15      AGRN  TTLL10  TNFRSF18  ...      ZFY  PCDH11Y  \
# ...
